# %% [markdown]
# # Preliminaries

# %% [markdown]
# ## To set up required PySpark and Spark versions, use examples given at:
# https://github.com/JohnSnowLabs/spark-nlp/blob/master/examples/python/annotation/text/english/stemmer/Word_Stemming_with_Stemmer.ipynb

# %%
# !wget http://setup.johnsnowlabs.com/colab.sh -O - | bash
# Out:
# --2023-04-12 16:48:15--  http://setup.johnsnowlabs.com/colab.sh
# Resolving setup.johnsnowlabs.com (setup.johnsnowlabs.com)... 51.158.130.125
# Connecting to setup.johnsnowlabs.com (setup.johnsnowlabs.com)|51.158.130.125|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://setup.johnsnowlabs.com/colab.sh [following]
# --2023-04-12 16:48:16--  https://setup.johnsnowlabs.com/colab.sh
# Connecting to setup.johnsnowlabs.com (setup.johnsnowlabs.com)|51.158.130.125|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://raw.githubusercontent.com/JohnSnowLabs/spark-nlp/master/scripts/colab_setup.sh [following]
# --2023-04-12 16:48:17--  https://raw.githubusercontent.com/JohnSnowLabs/spark-nlp/master/scripts/colab_setup.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1191 (1.2K) [text/plain]
# Saving to: ‘STDOUT’
#
# -                   100%[===================>]   1.16K  --.-KB/s    in 0s
#
# 2023-04-12 16:48:17 (80.6 MB/s) - written to stdout [1191/1191]
#
# Installing PySpark 3.2.3 and Spark NLP 4.4.0
# setup Colab for PySpark 3.2.3 and Spark NLP 4.4.0

# %%
from pyspark.ml import Pipeline

import sparknlp
from sparknlp.base import *
from sparknlp.annotator import *

spark = sparknlp.start()

print("Spark NLP version: ", sparknlp.version())
print("Apache Spark version: ", spark.version)

spark
# Out:
# Warning::Spark Session already created, some configs may not take.
# Spark NLP version:  4.4.0
# Apache Spark version:  3.2.3
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://17469a2f72e9:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.2.3</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Spark NLP</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 54.8 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %% [markdown]
# ## Add Other import statements

# %%
import pyspark.sql
from pyspark.sql import Row
from pyspark.sql.types import *
import json

# %%
import pandas as pd
import numpy as np
from pyspark.ml.classification import *
#from pyspark.ml.feature import *
#do not import the tokenizer and stop word remover from ml since it conflicts with the one from nlp
from pyspark.ml.feature import CountVectorizer, IDF, StringIndexer
from pyspark.ml.evaluation import MulticlassClassificationEvaluator

# %%
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.linalg import Vector

# %%
from sklearn.metrics import classification_report

# %% [markdown]
# # Import data

# %%
myPath = "/content/drive/My Drive/H516/genius_with_counts/"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from pyspark.sql.types import StructField, StructType, StringType,LongType

custom_schema = StructType([
    StructField("record", IntegerType(), False),
    StructField("id", StringType(), False),
    StructField("genre", StringType(), False),
    StructField("title", StringType(), False),
    StructField("artist", StringType(), False),
    StructField("year", IntegerType(), False),
    StructField("word_count", IntegerType(), False),
    StructField("unique_words", IntegerType(), False),
    StructField("repetition_pct", FloatType(), False),
    StructField("stopword_count", IntegerType(), False),
    StructField("stopword_pct", FloatType(), False),
    StructField("profanity_count", IntegerType(), False),
    StructField("profanity_pct", FloatType(), False),
    StructField("positive_count", IntegerType(), False),
    StructField("positive_pct", FloatType(), False),
    StructField("negative_count", IntegerType(), False),
    StructField("negative_pct", FloatType(), False),
    StructField("words_only_lyrics", StringType(),False)
])

# %%
rawdata_country = spark.read.format("csv") \
    .schema(custom_schema) \
    .option("header", True) \
    .load(myPath + 'genius_wCounts_country.csv')
rawdata_country.show(3)
# Out:
# +------+----+-------+-------------------+------------+----+----------+------------+--------------+--------------+------------+---------------+-------------+--------------+------------+--------------+------------+--------------------+
# |record|  id|  genre|              title|      artist|year|word_count|unique_words|repetition_pct|stopword_count|stopword_pct|profanity_count|profanity_pct|positive_count|positive_pct|negative_count|negative_pct|   words_only_lyrics|
# +------+----+-------+-------------------+------------+----+----------+------------+--------------+--------------+------------+---------------+-------------+--------------+------------+--------------+------------+--------------------+
# |     0|2504|country|1 Corinthians 15:55| Johnny Cash|2010|       214|          76|          0.64|            90|        0.42|              0|          0.0|             9|        0.04|             5|        0.02|O Death  where is...|
# |     1|2518|country| Bullets In The Gun|  Toby Keith|2010|       479|         180|          0.62|           179|        0.37|              0|          0.0|             7|        0.01|            18|        0.04| Verse   They use...|
# |     2|2520|country|               Mine|Taylor Swift|2010|       403|         130|          0.68|           150|        0.37|              0|          0.0|            10|        0.02|            13|        0.03| Verse   You were...|
# +------+----+-------+-------------------+------------+----+----------+------------+--------------+--------------+------------+---------------+-------------+--------------+------------+--------------+------------+--------------------+
# only showing top 3 rows

# %%
rawdata_pop = spark.read.format("csv") \
    .schema(custom_schema) \
    .option("header", True) \
    .load(myPath + 'genius_wCounts_pop.csv')
rawdata_pop.show(3)
# Out:
# +------+----+-----+-------------------+------------+----+----------+------------+--------------+--------------+------------+---------------+-------------+--------------+------------+--------------+------------+--------------------+
# |record|  id|genre|              title|      artist|year|word_count|unique_words|repetition_pct|stopword_count|stopword_pct|profanity_count|profanity_pct|positive_count|positive_pct|negative_count|negative_pct|   words_only_lyrics|
# +------+----+-----+-------------------+------------+----+----------+------------+--------------+--------------+------------+---------------+-------------+--------------+------------+--------------+------------+--------------------+
# |     0| 911|  pop|          Ego Remix|      Beyonc|2009|       662|         202|          0.69|           243|        0.37|              0|          0.0|            45|        0.07|            13|        0.02| Verse   Kanye We...|
# |     1|1321|  pop|Keep It Goin Louder| Major Lazer|2009|       510|          96|          0.81|           157|        0.31|             10|         0.02|            12|        0.02|            11|        0.02| Intro  Ricky Bla...|
# |     2|1533|  pop|            Be Free|Radio Killer|2010|       130|          21|          0.84|            42|        0.32|              0|          0.0|            16|        0.12|             2|        0.02|I care about love...|
# +------+----+-----+-------------------+------------+----+----------+------------+--------------+--------------+------------+---------------+-------------+--------------+------------+--------------+------------+--------------------+
# only showing top 3 rows

# %%
rawdata_rock = spark.read.format("csv") \
    .schema(custom_schema) \
    .option("header", True) \
    .load(myPath + 'genius_wCounts_rock.csv')
rawdata_rock.show(3)
# Out:
# +------+----+-----+--------------------+-----------+----+----------+------------+--------------+--------------+------------+---------------+-------------+--------------+------------+--------------+------------+--------------------+
# |record|  id|genre|               title|     artist|year|word_count|unique_words|repetition_pct|stopword_count|stopword_pct|profanity_count|profanity_pct|positive_count|positive_pct|negative_count|negative_pct|   words_only_lyrics|
# +------+----+-----+--------------------+-----------+----+----------+------------+--------------+--------------+------------+---------------+-------------+--------------+------------+--------------+------------+--------------------+
# |     0|1181| rock|Neighborhood 2 Laïka|Arcade Fire|2005|       199|          64|          0.68|            74|        0.37|              0|          0.0|             3|        0.02|             2|        0.01| Verse   Alexande...|
# |     1|1060| rock|    Hotel California|     Eagles|1976|       352|         152|          0.57|           128|        0.36|              0|          0.0|            13|        0.04|             6|        0.02| Verse   On a dar...|
# |     2|1188| rock|  Fake Plastic Trees|  Radiohead|1995|       174|          63|          0.64|            58|        0.33|              0|          0.0|             4|        0.02|             7|        0.04| Verse   A green ...|
# +------+----+-----+--------------------+-----------+----+----------+------------+--------------+--------------+------------+---------------+-------------+--------------+------------+--------------+------------+--------------------+
# only showing top 3 rows

# %%
rawdata_rb = spark.read.format("csv") \
    .schema(custom_schema) \
    .option("header", True) \
    .load(myPath + 'genius_wCounts_rb.csv')
rawdata_rb.show(3)
# Out:
# +------+---+-----+-----------------+--------+----+----------+------------+--------------+--------------+------------+---------------+-------------+--------------+------------+--------------+------------+--------------------+
# |record| id|genre|            title|  artist|year|word_count|unique_words|repetition_pct|stopword_count|stopword_pct|profanity_count|profanity_pct|positive_count|positive_pct|negative_count|negative_pct|   words_only_lyrics|
# +------+---+-----+-----------------+--------+----+----------+------------+--------------+--------------+------------+---------------+-------------+--------------+------------+--------------+------------+--------------------+
# |     0|235|   rb|   Miss You Remix| Aaliyah|2003|       733|         269|          0.63|           282|        0.38|              1|          0.0|            11|        0.02|            25|        0.03| Intro  JayZ    A...|
# |     1|664|   rb|         Ringtone|R. Kelly|2007|       377|         175|          0.54|           141|        0.37|              9|         0.02|             7|        0.02|             9|        0.02| Intro  Polow Da ...|
# |     2|791|   rb|All I Want Is You|  Miguel|2010|       540|         174|          0.68|           191|        0.35|              3|         0.01|            15|        0.03|            15|        0.03| Intro  J  Cole  ...|
# +------+---+-----+-----------------+--------+----+----------+------------+--------------+--------------+------------+---------------+-------------+--------------+------------+--------------+------------+--------------------+
# only showing top 3 rows

# %%
rawdata_rap = spark.read.format("csv") \
    .schema(custom_schema) \
    .option("header", True) \
    .load(myPath + 'genius_wCounts_rap.csv')
rawdata_rap.show(3)
# Out:
# +------+----+-----+--------------------+-------+----+----------+------------+--------------+--------------+------------+---------------+-------------+--------------+------------+--------------+------------+--------------------+
# |record|  id|genre|               title| artist|year|word_count|unique_words|repetition_pct|stopword_count|stopword_pct|profanity_count|profanity_pct|positive_count|positive_pct|negative_count|negative_pct|   words_only_lyrics|
# +------+----+-----+--------------------+-------+----+----------+------------+--------------+--------------+------------+---------------+-------------+--------------+------------+--------------+------------+--------------------+
# |     0|  11|  rap|       Lord You Know|Cam'ron|2004|       831|         319|          0.62|           280|        0.34|              7|         0.01|            25|        0.03|            36|        0.04| Chorus  Jaheim  ...|
# |     1|  18|  rap|Its Hot Some Like...|  JAY-Z|1999|       645|         208|          0.68|           188|        0.29|             16|         0.02|            33|        0.05|            35|        0.05| Produced by Timb...|
# |     2|8717|  rap|                Time|     AZ|2004|       459|         251|          0.45|           156|        0.34|              5|         0.01|            15|        0.03|            23|        0.05| Verse   Nature  ...|
# +------+----+-----+--------------------+-------+----+----------+------------+--------------+--------------+------------+---------------+-------------+--------------+------------+--------------+------------+--------------------+
# only showing top 3 rows

# %%
all_genresDF = rawdata_country.union(rawdata_pop).union(rawdata_rock).union(rawdata_rb).union(rawdata_rap)
all_genresDF.show(3)
# Out:
# +------+----+-------+-------------------+------------+----+----------+------------+--------------+--------------+------------+---------------+-------------+--------------+------------+--------------+------------+--------------------+
# |record|  id|  genre|              title|      artist|year|word_count|unique_words|repetition_pct|stopword_count|stopword_pct|profanity_count|profanity_pct|positive_count|positive_pct|negative_count|negative_pct|   words_only_lyrics|
# +------+----+-------+-------------------+------------+----+----------+------------+--------------+--------------+------------+---------------+-------------+--------------+------------+--------------+------------+--------------------+
# |     0|2504|country|1 Corinthians 15:55| Johnny Cash|2010|       214|          76|          0.64|            90|        0.42|              0|          0.0|             9|        0.04|             5|        0.02|O Death  where is...|
# |     1|2518|country| Bullets In The Gun|  Toby Keith|2010|       479|         180|          0.62|           179|        0.37|              0|          0.0|             7|        0.01|            18|        0.04| Verse   They use...|
# |     2|2520|country|               Mine|Taylor Swift|2010|       403|         130|          0.68|           150|        0.37|              0|          0.0|            10|        0.02|            13|        0.03| Verse   You were...|
# +------+----+-------+-------------------+------------+----+----------+------------+--------------+--------------+------------+---------------+-------------+--------------+------------+--------------+------------+--------------------+
# only showing top 3 rows

# %%
all_genresDF.printSchema()
# Out:
# root
#  |-- record: integer (nullable = true)
#  |-- id: string (nullable = true)
#  |-- genre: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- artist: string (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- word_count: integer (nullable = true)
#  |-- unique_words: integer (nullable = true)
#  |-- repetition_pct: float (nullable = true)
#  |-- stopword_count: integer (nullable = true)
#  |-- stopword_pct: float (nullable = true)
#  |-- profanity_count: integer (nullable = true)
#  |-- profanity_pct: float (nullable = true)
#  |-- positive_count: integer (nullable = true)
#  |-- positive_pct: float (nullable = true)
#  |-- negative_count: integer (nullable = true)
#  |-- negative_pct: float (nullable = true)
#  |-- words_only_lyrics: string (nullable = true)

# %%
all_genresDF.createOrReplaceTempView("model_input")

# %%
lyricGenres = spark.sql("SELECT genre,  COUNT(1) AS TTL_RCRDS FROM model_input WHERE genre IN('country','pop','rap','rb','rock')  AND words_only_lyrics is not null and artist not like '%Genius%' and artist not like '%Translations%' GROUP BY genre")
lyricGenres.show(100)
# Out:
# +-------+---------+
# |  genre|TTL_RCRDS|
# +-------+---------+
# |country|    86598|
# |    pop|    86575|
# |   rock|    86321|
# |     rb|    86504|
# |    rap|    86433|
# +-------+---------+

# %%
#change data volume as needed
#volume = 60000
p1 = 1 #volume/86598
p2 = 1 #volume/86575
p3 = 1 #volume/86321
p4 = 1 #volume/86504
p5 = 1 #volume/86433
lyricSample = all_genresDF.sampleBy("genre", {'country': p1, 'pop': p2,  'rock': p3 ,'rb': p4, 'rap': p5},0)

# %%
lyricSample.createOrReplaceTempView("sample")

# %%
sampleGenres = spark.sql("SELECT genre,  COUNT(1) AS TTL_RCRDS FROM sample WHERE genre IN('country','pop','rap','rb','rock')  AND words_only_lyrics is not null and artist not like '%Genius%' and artist not like '%Translations%' GROUP BY genre")
sampleGenres.show(100)
# Out:
# +-------+---------+
# |  genre|TTL_RCRDS|
# +-------+---------+
# |country|    86598|
# |    pop|    86575|
# |   rock|    86321|
# |     rb|    86504|
# |    rap|    86433|
# +-------+---------+

# %%
model_inputDF = spark.sql("SELECT a.*, CASE WHEN a.genre = 'country' THEN 0 WHEN a.genre = 'pop' THEN 1 WHEN a.genre = 'rap' THEN 2 WHEN a.genre = 'rb' THEN 3 WHEN a.genre = 'rock' THEN 4 ELSE 9 END AS label FROM sample a WHERE genre IN('country','pop','rap','rb','rock') AND words_only_lyrics is not null and word_count is not null and artist not like '%Genius%' and artist not like '%Translations%'")
model_inputDF.show(truncate=150)
# Out:
# +------+-----+-------+-----------------------------+-------------+----+----------+------------+--------------+--------------+------------+---------------+-------------+--------------+------------+--------------+------------+------------------------------------------------------------------------------------------------------------------------------------------------------+-----+
# |record|   id|  genre|                        title|       artist|year|word_count|unique_words|repetition_pct|stopword_count|stopword_pct|profanity_count|profanity_pct|positive_count|positive_pct|negative_count|negative_pct|                                                                                                                                     words_only_lyrics|label|
# +------+-----+-------+-----------------------------+-------------+----+----------+------------+--------------+--------------+------------+---------------+-------------+--------------+------------+--------------+------------+------------------------------------------------------------------------------------------------------------------------------------------------------+-----+
# |     0| 2504|country|          1 Corinthians 15:55|  Johnny Cash|2010|       214|          76|          0.64|            90|        0.42|              0|          0.0|             9|        0.04|             5|        0.02|O Death  where is thy sting O Grave  where is thy victory O Life  you are a shining path And hope springs eternal  just over the rise When I see my...|    0|
# |     1| 2518|country|           Bullets In The Gun|   Toby Keith|2010|       479|         180|          0.62|           179|        0.37|              0|          0.0|             7|        0.01|            18|        0.04| Verse   They used to call me lightning I was always quick to strike Had everything I own In the saddles on my bike I had a reputation For never st...|    0|
# |     2| 2520|country|                         Mine| Taylor Swift|2010|       403|         130|          0.68|           150|        0.37|              0|          0.0|            10|        0.02|            13|        0.03| Verse   You were in college  working parttime  waiting tables Left a small town and never looked back I was a flight risk  with a fear of falling ...|    0|
# |     3| 2873|country|          Rocky Mountain High|  John Denver|1972|       365|         136|          0.63|           121|        0.33|              0|          0.0|             7|        0.02|             6|        0.02| Verse   He was born in the summer of his th year Comin home to a place he’d never been before He left yesterday behind him  you might say he was b...|    0|
# |     4| 3499|country|                     Fuck Off|     Kid Rock|1998|       693|         289|          0.58|           244|        0.35|             31|         0.04|            21|        0.03|            45|        0.06| Verse   Kid Rock  A shimmy shimmy go go motherfucking pop  bitch Its the KKKid Rock with the KKKid Rock shit Im on top bitch and rock for tricks H...|    0|
# |     5| 3774|country|             Back to December| Taylor Swift|2010|       432|         122|          0.72|           167|        0.39|              0|          0.0|            19|        0.04|            13|        0.03| Verse   Im so glad you made time to see me Hows life Tell me  hows your family I havent seen them in a while Youve been good  busier than ever We ...|    0|
# |     6| 4333|country|              All Summer Long|     Kid Rock|2007|       390|         115|          0.71|           117|         0.3|              0|          0.0|            11|        0.03|             6|        0.02| Intro  It was   my thoughts were short my hair was long Caught somewhere between a boy and man She was seventeen and she was far from inbetween It...|    0|
# |     7| 4462|country|       Shouldve Been a Cowboy|   Toby Keith|1993|       285|         108|          0.62|           100|        0.35|              0|          0.0|             5|        0.02|             6|        0.02| Verse   I bet you have never heard ol Marshal Dillon say Miss Kitty  have you ever thought of running away Settling down  would you marry me If I ...|    0|
# |     8| 5927|country|                       Heaven|Uncle Kracker|2000|       707|         245|          0.65|           254|        0.36|             14|         0.02|            14|        0.02|            18|        0.03| Kracker   If Heaven aint alot like Detroit  I dont wanna go  If Heaven aint alot like Detroit  I just a soon stay home  If they aint got no Eight ...|    0|
# |     9|14806|country|              My Last Yee Haw|  Cowboy Troy|2005|       508|         135|          0.73|           155|        0.31|              1|          0.0|            18|        0.04|            18|        0.04| Intro  Get freaky Somebody scare the shit out of me right now   Intro  Larry the Cable Guy  Test two  test two three  test two niner five Hey  Git...|    0|
# |    10|14797|country|               Aint Broke Yet|  Cowboy Troy|2005|       607|         154|          0.75|           163|        0.27|              0|          0.0|             4|        0.01|            36|        0.06| Chorus  Big  Rich  Well he aint broke yet but hes sho nuff bendin Well he aint broke yet but hes sho nuff bendin Well he aint broke yet but hes sh...|    0|
# |    11|14799|country|             Beast on the Mic|  Cowboy Troy|2005|       263|         127|          0.52|            83|        0.32|              0|          0.0|             4|        0.02|             3|        0.01| Chorus  James Otto  Im a beast on the mic  cant get no satisfaction Step aside cause its time for some action Im a hick rhyme sayer with a kung fu...|    0|
# |    12|14800|country|                    El Tejano|  Cowboy Troy|2005|       277|         146|          0.47|            77|        0.28|              0|          0.0|             8|        0.03|             2|        0.01| Verse   Escuchen a la musica  the beat is groovin ya Groovin with the record in secreto y la publica Its the Cowboy with the fresh genre The groov...|    0|
# |    13|14801|country|                Do Your Thang|  Cowboy Troy|2005|       332|         148|          0.55|           123|        0.37|              1|          0.0|            21|        0.06|             2|        0.01| Jill Kinsey  In a smoky room  I see you And youre dancin to a groovin tune Just mellow out  shake your mmmm And do your thang  baby do your thang ...|    0|
# |    14|14802|country|             Crick in My Neck|  Cowboy Troy|2005|       260|         108|          0.58|           100|        0.38|              0|          0.0|             7|        0.03|             2|        0.01| Chorus  Mmm hmm Got a crick in my neck Mmm hmm Got a crick in my neck   Repeat Chorus x     Verse   Well we enter the facility  the place is jumpi...|    0|
# |    15|14803|country|                    Automatic|  Cowboy Troy|2005|       249|         100|           0.6|            99|         0.4|              0|          0.0|             6|        0.02|             3|        0.01| Verse   Cowboy Troy  Shes sittin at the bar  sippinon a beverage Try to use your platinum card to get leverage It dont matter  shes got her own Sh...|    0|
# |    16|14804|country|       Somebodys Smilin On Me|  Cowboy Troy|2005|       343|         150|          0.56|           118|        0.34|              0|          0.0|             9|        0.03|             7|        0.02| Verse   Cowboy Troy  Like dust in the wind sand slips through your fingers Similar to shattered dreams that still linger Trying to succeed in what...|    0|
# |    17|14808|country|                  Whoop Whoop|  Cowboy Troy|2005|       325|         153|          0.53|            99|         0.3|              0|          0.0|            14|        0.04|             5|        0.02| Jon Nicholson  Whoop Whoop whoop Theres just something bout your   Chorus  Jon Nicholson  Whoop whoop It makes me wanna whoop whoop I just cant he...|    0|
# |    18|14809|country|    If You Dont Wanna Love Me|  Cowboy Troy|2005|       483|         184|          0.62|           170|        0.35|              0|          0.0|            18|        0.04|            16|        0.03| Chorus x   Sarah Buxton  If you dont wanna love me Then Ill find somebody else who will Find another kind of thrill Find another way to fill this ...|    0|
# |    19|14813|country|I Play Chicken With The Train|  Cowboy Troy|2005|       474|         154|          0.68|           127|        0.27|              0|          0.0|             6|        0.01|             9|        0.02| Hook  Big  Rich  I play chicken with the train Play chicken with the train train Unh huh huh unh huh huh You know that I play chicken with the tra...|    0|
# +------+-----+-------+-----------------------------+-------------+----+----------+------------+--------------+--------------+------------+---------------+-------------+--------------+------------+--------------+------------+------------------------------------------------------------------------------------------------------------------------------------------------------+-----+
# only showing top 20 rows

# %% [markdown]
# # Perform pre-processing of data using a PySpark nlp pipeline

# %%
target_names = ['country','pop', 'rap', 'rb', 'rock']

# %%
# %%time
documentAssembler = DocumentAssembler()\
    .setInputCol("words_only_lyrics")\
    .setOutputCol("document")

sentence = SentenceDetector()\
    .setInputCols(["document"]) \
    .setOutputCol("sentences")

tokenizer = Tokenizer()\
    .setInputCols(["sentences"]) \
    .setOutputCol("token")

stopWords = StopWordsCleaner() \
    .setInputCols(["token"]) \
    .setOutputCol("cleanTokens") \
    .setCaseSensitive(False)

lemmatizer = LemmatizerModel.pretrained()\
    .setInputCols(["cleanTokens"]) \
    .setOutputCol("lemma")

normalizer  = Normalizer()\
    .setInputCols(["lemma"]) \
    .setOutputCol("normalized") \
    .setLowercase(True)

finisher = Finisher()\
    .setInputCols(["normalized"]) \
    .setOutputCols("normalized")\
    .setOutputAsArray(True)

count_vectorizer = CountVectorizer(
    inputCol="normalized",
    outputCol="tf"
)

tf_idf = IDF(
    inputCol="tf",
    outputCol="tf_idf"
)

#stemmer not used this time (bc lemmatizer used instead) but save syntax for later
#stemmer = Stemmer() \
    #.setInputCols(["token"]) \
    #.setOutputCol("stem")
# Out:
# lemma_antbnc download started this may take some time.
# Approximate size to download 907.6 KB
# [OK!]
# CPU times: user 60.6 ms, sys: 10.9 ms, total: 71.5 ms
# Wall time: 5.32 s

# %%
nlpPipeline = Pipeline(stages=[documentAssembler,
                               sentence,
                               tokenizer,
                               stopWords,
                               lemmatizer,
                               normalizer,
                               finisher,
                               count_vectorizer,
                               tf_idf])

# %%
#add additional feature columns to the cleaned text that is output from the nlp pipeline
# %%time
xtra_cols = VectorAssembler(inputCols=['tf_idf','word_count'], outputCol='features')
# Out:
# CPU times: user 1.82 ms, sys: 0 ns, total: 1.82 ms
# Wall time: 4.3 ms

# %%
pipeline = Pipeline(stages=[nlpPipeline, xtra_cols])

# %%
#create feature vectors for all of the model input
# %%time
processed = pipeline.fit(model_inputDF).transform(model_inputDF)
# Out:
# CPU times: user 9.68 s, sys: 1.16 s, total: 10.8 s
# Wall time: 28min 7s

# %%
processed.show(truncate=40)
# Out:
# +------+-----+-------+-----------------------------+-------------+----+----------+------------+--------------+--------------+------------+---------------+-------------+--------------+------------+--------------+------------+----------------------------------------+-----+----------------------------------------+----------------------------------------+----------------------------------------+----------------------------------------+
# |record|   id|  genre|                        title|       artist|year|word_count|unique_words|repetition_pct|stopword_count|stopword_pct|profanity_count|profanity_pct|positive_count|positive_pct|negative_count|negative_pct|                       words_only_lyrics|label|                              normalized|                                      tf|                                  tf_idf|                                features|
# +------+-----+-------+-----------------------------+-------------+----+----------+------------+--------------+--------------+------------+---------------+-------------+--------------+------------+--------------+------------+----------------------------------------+-----+----------------------------------------+----------------------------------------+----------------------------------------+----------------------------------------+
# |     0| 2504|country|          1 Corinthians 15:55|  Johnny Cash|2010|       214|          76|          0.64|            90|        0.42|              0|          0.0|             9|        0.04|             5|        0.02|O Death  where is thy sting O Grave  ...|    0|[o, death, thou, sting, o, grave, tho...|(262144,[3,12,13,14,15,16,26,34,35,37...|(262144,[3,12,13,14,15,16,26,34,35,37...|(262145,[3,12,13,14,15,16,26,34,35,37...|
# |     1| 2518|country|           Bullets In The Gun|   Toby Keith|2010|       479|         180|          0.62|           179|        0.37|              0|          0.0|             7|        0.01|            18|        0.04| Verse   They used to call me lightni...|    0|[verse, use, call, lightning, always,...|(262144,[1,4,6,7,8,10,12,13,15,16,20,...|(262144,[1,4,6,7,8,10,12,13,15,16,20,...|(262145,[1,4,6,7,8,10,12,13,15,16,20,...|
# |     2| 2520|country|                         Mine| Taylor Swift|2010|       403|         130|          0.68|           150|        0.37|              0|          0.0|            10|        0.02|            13|        0.03| Verse   You were in college  working...|    0|[verse, college, work, parttime, wait...|(262144,[0,1,2,4,5,7,8,9,10,11,12,13,...|(262144,[0,1,2,4,5,7,8,9,10,11,12,13,...|(262145,[0,1,2,4,5,7,8,9,10,11,12,13,...|
# |     3| 2873|country|          Rocky Mountain High|  John Denver|1972|       365|         136|          0.63|           121|        0.33|              0|          0.0|             7|        0.02|             6|        0.02| Verse   He was born in the summer of...|    0|[verse, bear, summer, th, year, comin...|(262144,[1,2,3,8,9,10,12,15,20,21,35,...|(262144,[1,2,3,8,9,10,12,15,20,21,35,...|(262145,[1,2,3,8,9,10,12,15,20,21,35,...|
# |     4| 3499|country|                     Fuck Off|     Kid Rock|1998|       693|         289|          0.58|           244|        0.35|             31|         0.04|            21|        0.03|            45|        0.06| Verse   Kid Rock  A shimmy shimmy go...|    0|[verse, kid, rock, shimmy, shimmy, go...|(262144,[0,1,2,3,4,6,7,8,9,11,12,13,1...|(262144,[0,1,2,3,4,6,7,8,9,11,12,13,1...|(262145,[0,1,2,3,4,6,7,8,9,11,12,13,1...|
# |     5| 3774|country|             Back to December| Taylor Swift|2010|       432|         122|          0.72|           167|        0.39|              0|          0.0|            19|        0.04|            13|        0.03| Verse   Im so glad you made time to ...|    0|[verse, im, glad, make, time, see, ho...|(262144,[0,2,5,6,8,9,10,11,12,13,15,1...|(262144,[0,2,5,6,8,9,10,11,12,13,15,1...|(262145,[0,2,5,6,8,9,10,11,12,13,15,1...|
# |     6| 4333|country|              All Summer Long|     Kid Rock|2007|       390|         115|          0.71|           117|         0.3|              0|          0.0|            11|        0.03|             6|        0.02| Intro  It was   my thoughts were sho...|    0|[intro, thoughts, short, hair, long, ...|(262144,[4,5,7,8,12,15,20,28,32,34,35...|(262144,[4,5,7,8,12,15,20,28,32,34,35...|(262145,[4,5,7,8,12,15,20,28,32,34,35...|
# |     7| 4462|country|       Shouldve Been a Cowboy|   Toby Keith|1993|       285|         108|          0.62|           100|        0.35|              0|          0.0|             5|        0.02|             6|        0.02| Verse   I bet you have never heard o...|    0|[verse, bet, never, hear, ol, marshal...|(262144,[4,6,7,8,9,10,14,20,29,32,36,...|(262144,[4,6,7,8,9,10,14,20,29,32,36,...|(262145,[4,6,7,8,9,10,14,20,29,32,36,...|
# |     8| 5927|country|                       Heaven|Uncle Kracker|2000|       707|         245|          0.65|           254|        0.36|             14|         0.02|            14|        0.02|            18|        0.03| Kracker   If Heaven aint alot like D...|    0|[kracker, heaven, aint, alot, like, d...|(262144,[0,1,2,3,4,5,6,11,12,17,20,21...|(262144,[0,1,2,3,4,5,6,11,12,17,20,21...|(262145,[0,1,2,3,4,5,6,11,12,17,20,21...|
# |     9|14806|country|              My Last Yee Haw|  Cowboy Troy|2005|       508|         135|          0.73|           155|        0.31|              1|          0.0|            18|        0.04|            18|        0.04| Intro  Get freaky Somebody scare the...|    0|[intro, get, freaky, somebody, scare,...|(262144,[0,1,2,3,4,6,7,8,10,11,13,16,...|(262144,[0,1,2,3,4,6,7,8,10,11,13,16,...|(262145,[0,1,2,3,4,6,7,8,10,11,13,16,...|
# |    10|14797|country|               Aint Broke Yet|  Cowboy Troy|2005|       607|         154|          0.75|           163|        0.27|              0|          0.0|             4|        0.01|            36|        0.06| Chorus  Big  Rich  Well he aint brok...|    0|[chorus, big, rich, well, aint, break...|(262144,[0,1,3,8,9,10,11,12,13,18,19,...|(262144,[0,1,3,8,9,10,11,12,13,18,19,...|(262145,[0,1,3,8,9,10,11,12,13,18,19,...|
# |    11|14799|country|             Beast on the Mic|  Cowboy Troy|2005|       263|         127|          0.52|            83|        0.32|              0|          0.0|             4|        0.02|             3|        0.01| Chorus  James Otto  Im a beast on th...|    0|[chorus, james, otto, im, beast, mic,...|(262144,[0,1,3,6,8,10,12,13,16,17,19,...|(262144,[0,1,3,6,8,10,12,13,16,17,19,...|(262145,[0,1,3,6,8,10,12,13,16,17,19,...|
# |    12|14800|country|                    El Tejano|  Cowboy Troy|2005|       277|         146|          0.47|            77|        0.28|              0|          0.0|             8|        0.03|             2|        0.01| Verse   Escuchen a la musica  the be...|    0|[verse, escuchen, la, musica, beat, g...|(262144,[0,1,4,7,8,9,10,11,15,16,22,2...|(262144,[0,1,4,7,8,9,10,11,15,16,22,2...|(262145,[0,1,4,7,8,9,10,11,15,16,22,2...|
# |    13|14801|country|                Do Your Thang|  Cowboy Troy|2005|       332|         148|          0.55|           123|        0.37|              1|          0.0|            21|        0.06|             2|        0.01| Jill Kinsey  In a smoky room  I see ...|    0|[jill, kinsey, smoky, room, see, your...|(262144,[1,2,4,5,6,8,9,10,12,16,18,22...|(262144,[1,2,4,5,6,8,9,10,12,16,18,22...|(262145,[1,2,4,5,6,8,9,10,12,16,18,22...|
# |    14|14802|country|             Crick in My Neck|  Cowboy Troy|2005|       260|         108|          0.58|           100|        0.38|              0|          0.0|             7|        0.03|             2|        0.01| Chorus  Mmm hmm Got a crick in my ne...|    0|[chorus, mmm, hmm, got, crick, neck, ...|(262144,[1,4,6,8,9,10,11,15,23,25,27,...|(262144,[1,4,6,8,9,10,11,15,23,25,27,...|(262145,[1,4,6,8,9,10,11,15,23,25,27,...|
# |    15|14803|country|                    Automatic|  Cowboy Troy|2005|       249|         100|           0.6|            99|         0.4|              0|          0.0|             6|        0.02|             3|        0.01| Verse   Cowboy Troy  Shes sittin at ...|    0|[verse, cowboy, troy, shes, sittin, b...|(262144,[1,2,3,6,8,9,10,11,12,13,16,1...|(262144,[1,2,3,6,8,9,10,11,12,13,16,1...|(262145,[1,2,3,6,8,9,10,11,12,13,16,1...|
# |    16|14804|country|       Somebodys Smilin On Me|  Cowboy Troy|2005|       343|         150|          0.56|           118|        0.34|              0|          0.0|             9|        0.03|             7|        0.02| Verse   Cowboy Troy  Like dust in th...|    0|[verse, cowboy, troy, like, dust, win...|(262144,[0,2,4,5,8,9,10,11,12,15,16,1...|(262144,[0,2,4,5,8,9,10,11,12,15,16,1...|(262145,[0,2,4,5,8,9,10,11,12,15,16,1...|
# |    17|14808|country|                  Whoop Whoop|  Cowboy Troy|2005|       325|         153|          0.53|            99|         0.3|              0|          0.0|            14|        0.04|             5|        0.02| Jon Nicholson  Whoop Whoop whoop The...|    0|[jon, nicholson, whoop, whoop, whoop,...|(262144,[0,1,4,5,6,8,9,10,11,13,15,16...|(262144,[0,1,4,5,6,8,9,10,11,13,15,16...|(262145,[0,1,4,5,6,8,9,10,11,13,15,16...|
# |    18|14809|country|    If You Dont Wanna Love Me|  Cowboy Troy|2005|       483|         184|          0.62|           170|        0.35|              0|          0.0|            18|        0.04|            16|        0.03| Chorus x   Sarah Buxton  If you dont...|    0|[chorus, x, sarah, buxton, dont, wann...|(262144,[1,2,3,4,5,6,8,9,10,11,12,13,...|(262144,[1,2,3,4,5,6,8,9,10,11,12,13,...|(262145,[1,2,3,4,5,6,8,9,10,11,12,13,...|
# |    19|14813|country|I Play Chicken With The Train|  Cowboy Troy|2005|       474|         154|          0.68|           127|        0.27|              0|          0.0|             6|        0.01|             9|        0.02| Hook  Big  Rich  I play chicken with...|    0|[hook, big, rich, play, chicken, trai...|(262144,[0,1,2,4,6,7,8,9,11,12,13,15,...|(262144,[0,1,2,4,6,7,8,9,11,12,13,15,...|(262145,[0,1,2,4,6,7,8,9,11,12,13,15,...|
# +------+-----+-------+-----------------------------+-------------+----+----------+------------+--------------+--------------+------------+---------------+-------------+--------------+------------+--------------+------------+----------------------------------------+-----+----------------------------------------+----------------------------------------+----------------------------------------+----------------------------------------+
# only showing top 20 rows

# %%
#split the data into training and test data sets
train, test = processed.randomSplit([0.7,0.3], seed=123)

# %% [markdown]
# # Train a Naive Bayes model on the training data and predict classes in the test data

# %%
#declare the model
naive_bayes = NaiveBayes(featuresCol='features')

# %%
#fit the nb model to the processed model
# %%time
model = naive_bayes.fit(train)
# Out:
# CPU times: user 4.92 s, sys: 567 ms, total: 5.48 s
# Wall time: 14min 34s

# %%
#create model predictions on the test data
# %%time
results = model.transform(test)
# Out:
# CPU times: user 4.86 ms, sys: 0 ns, total: 4.86 ms
# Wall time: 100 ms

# %%
results.show(5)
# Out:
# +------+-----+-------+---------------+------------+----+----------+------------+--------------+--------------+------------+---------------+-------------+--------------+------------+--------------+------------+--------------------+-----+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----------+
# |record|   id|  genre|          title|      artist|year|word_count|unique_words|repetition_pct|stopword_count|stopword_pct|profanity_count|profanity_pct|positive_count|positive_pct|negative_count|negative_pct|   words_only_lyrics|label|          normalized|                  tf|              tf_idf|            features|       rawPrediction|         probability|prediction|
# +------+-----+-------+---------------+------------+----+----------+------------+--------------+--------------+------------+---------------+-------------+--------------+------------+--------------+------------+--------------------+-----+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----------+
# |     2| 2520|country|           Mine|Taylor Swift|2010|       403|         130|          0.68|           150|        0.37|              0|          0.0|            10|        0.02|            13|        0.03| Verse   You were...|    0|[verse, college, ...|(262144,[0,1,2,4,...|(262144,[0,1,2,4,...|(262145,[0,1,2,4,...|[-4626.9622060942...|[1.0,1.6825675430...|       0.0|
# |     6| 4333|country|All Summer Long|    Kid Rock|2007|       390|         115|          0.71|           117|         0.3|              0|          0.0|            11|        0.03|             6|        0.02| Intro  It was   ...|    0|[intro, thoughts,...|(262144,[4,5,7,8,...|(262144,[4,5,7,8,...|(262145,[4,5,7,8,...|[-7222.7214263250...|[1.0,4.4202990103...|       0.0|
# |     9|14806|country|My Last Yee Haw| Cowboy Troy|2005|       508|         135|          0.73|           155|        0.31|              1|          0.0|            18|        0.04|            18|        0.04| Intro  Get freak...|    0|[intro, get, frea...|(262144,[0,1,2,3,...|(262144,[0,1,2,3,...|(262145,[0,1,2,3,...|[-12817.666539254...|[1.0,1.8493467532...|       0.0|
# |    12|14800|country|      El Tejano| Cowboy Troy|2005|       277|         146|          0.47|            77|        0.28|              0|          0.0|             8|        0.03|             2|        0.01| Verse   Escuchen...|    0|[verse, escuchen,...|(262144,[0,1,4,7,...|(262144,[0,1,4,7,...|(262145,[0,1,4,7,...|[-11741.557708427...|[0.0,2.1167377230...|       2.0|
# |    13|14801|country|  Do Your Thang| Cowboy Troy|2005|       332|         148|          0.55|           123|        0.37|              1|          0.0|            21|        0.06|             2|        0.01| Jill Kinsey  In ...|    0|[jill, kinsey, sm...|(262144,[1,2,4,5,...|(262144,[1,2,4,5,...|(262145,[1,2,4,5,...|[-7103.0315344084...|[2.69190651652148...|       2.0|
# +------+-----+-------+---------------+------------+----+----------+------------+--------------+--------------+------------+---------------+-------------+--------------+------------+--------------+------------+--------------------+-----+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----------+
# only showing top 5 rows

# %%
y_true = results.select(['label']).rdd.collect()
y_pred = results.select(['prediction']).rdd.collect()

# %%
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      country       0.62      0.69      0.65     25738
#          pop       0.37      0.23      0.28     25831
#          rap       0.78      0.75      0.76     25831
#           rb       0.55      0.59      0.57     26001
#         rock       0.49      0.60      0.54     25800
#
#     accuracy                           0.57    129201
#    macro avg       0.56      0.57      0.56    129201
# weighted avg       0.56      0.57      0.56    129201
